# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('testWalk1.csv')

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df = df.rename(columns={'Speed (m/s)': "speed"})

# %%
df = df.drop(df[df.Latitude == 0.0].index)

# %%
df
# Out:
#           time     gFx     gFy     gFz      ax      ay      az      wx  \
# 1        0.107  0.0275  0.4425  0.9132  0.0000  0.0000  0.0000  0.0000
# 2        0.109  0.0292  0.4316  0.9181  0.0000  0.0000  0.0000  0.0000
# 3        0.110  0.0390  0.4341  0.9198  0.0000  0.0000  0.0000  0.0000
# 4        0.111  0.0390  0.4341  0.9198  0.0000  0.0000  0.0000 -0.0717
# 5        0.112  0.0390  0.4341  0.9198  0.0000  0.0000 -0.0000 -0.0717
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 69292  831.161  0.1656  0.4731  0.5976 -0.1443  1.1523 -1.6092 -0.0898
# 69293  831.214  0.1555  0.5101  0.6912 -0.1443  1.1523 -1.6092 -0.0898
# 69294  831.215  0.1263  0.5572  0.8447 -0.1443  1.1523 -1.6092 -0.0898
# 69295  831.216  0.0837  0.5649  0.9514 -0.1443  1.1523 -1.6092 -0.0898
# 69296  831.217  0.0729  0.5321  0.9969 -0.1443  1.1523 -1.6092 -0.0898
#
#            wy      wz   Latitude   Longitude  speed
# 1      0.0000  0.0000  49.259349 -123.044073   0.00
# ...

# %%
plt.plot(df['time'], df['speed'])

# %%
def getDistanceFromLatLonInKm(lat,lon):
    R = 6371; # Radius of the earth in km
    dLat = deg2rad((lat.shift(-1) - lat).dropna());  # deg2rad below
    dLon = deg2rad((lon.shift(-1) - lon).dropna()); 
    a = np.sin(dLat/2) * np.sin(dLat/2) + np.cos(deg2rad(lat)) * np.cos(deg2rad(lat.shift(-1))) * np.sin(dLon/2) * np.sin(dLon/2)
    
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a)); 
    d = R * c * 1000; # Distance in km
    return d


def deg2rad(deg):
    return deg * (np.pi/180)

# %%
getDistanceFromLatLonInKm(df['Latitude'], df['Longitude']).sum()
# Out:
# 1146.4632437679177

# %%
dist = df['speed'].shift(-1) * (df['time'].shift(-1) - df['time'])

# %%
dist.sum()
# Out:
# 1095.88421928355

# %%
diff = (df['time'].shift(-1) - df['time'])

# %%
diff
# Out:
# 1        0.002
# 2        0.001
# 3        0.001
# 4        0.001
# 5        0.032
#          ...
# 69292    0.053
# 69293    0.001
# 69294    0.001
# 69295    0.001
# 69296      NaN
# Name: time, Length: 69296, dtype: float64

# %%
plt.plot(df['time'], df['gFx'])

# %%
plt.plot(df['time'], df['gFy'])

# %%
plt.plot(df['time'], df['gFz'])

# %%
plt.plot(df['time'], df['ax'])

# %%
plt.plot(df['time'], df['ay'])

# %%
plt.plot(df['time'], df['az'])

# %%
plt.plot(df['time'], df['wx'])

# %%
plt.plot(df['time'], df['wy'])

# %%
plt.plot(df['time'], df['wz'])
